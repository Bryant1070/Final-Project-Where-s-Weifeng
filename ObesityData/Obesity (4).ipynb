# %%
import pandas as pd

# Load the data from a CSV file
df = pd.read_csv('ObesityData.csv')

# strip the data frame so it only contains the data (columns) that I want
stripped_df = df[['City Neighborhood', '2006-2010 estimate of obesity']]

#sort the data frame so that the obesity rates are in descending order. 
new_df_sorted = stripped_df.sort_values(by='2006-2010 estimate of obesity', ascending=False)

# Reset the index to apply weight to eat Neighborhood (Find 1st place)
new_df_sorted = new_df_sorted.reset_index(drop=True)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Print the entire dataframe
new_df_sorted.head(200)
# Out:
#              City Neighborhood  2006-2010 estimate of obesity
# 0            Northview Heights                       0.922932
# 1                    Fairywood                       0.820311
# 2              Terrace-Village                       0.793133
# 3         California-Kirkbride                       0.771046
# 4                  Saint-Clair                       0.699500
# 5    Central-Business-District                       0.668012
# 6               Homewood-South                       0.660585
# 7     Lincoln-Lemington-Belmar                       0.637099
# 8            Bedford-Dwellings                       0.636222
# 9               Homewood-North                       0.619584
# 10                 Middle-Hill                       0.608099
# 11          Marshall-Shadeland                       0.606853
# 12                    Garfield                       0.576886
# 13    Lincoln-Lemington-Belmar                       0.574293
# 14              Homewood-North                       0.573266
# 15               Homewood-West                       0.565710
# 16                  East Hills                       0.562137
# 17                     Larimer                       0.560448
# 18              Homewood-South                       0.558809
# 19             Terrace-Village                       0.555073
# 20                    Garfield                       0.547886
# 21    Lincoln-Lemington-Belmar                       0.525315
# 22                    Fineview                       0.499129
# 23                  Manchester                       0.498043
# 24                 Perry-South                       0.495057
# 25            Crawford-Roberts                       0.488691
# 26           Central-Northside                       0.487121
# 27                 Beltzhoover                       0.479978
# 28                     Larimer                       0.474671
# 29           Arlington-Heights                       0.473120
# 30                  Upper-Hill                       0.455786
# 31                    Garfield                       0.450580
# 32                East-Liberty                       0.445041
# 33                     Chateau                       0.439386
# 34              Chartiers-City                       0.438445
# 35                East-Liberty                       0.414947
# 36                 Perry-South                       0.411792
# 37                   Hazelwood                       0.399853
# 38           Central-Northside                       0.397141
# 39                   Knoxville                       0.390727
# 40              East-Allegheny                       0.388731
# 41                  Glen-Hazel                       0.383138
# 42   Mount-Oliver Neighborhood                       0.380567
# 43                   Hazelwood                       0.371847
# 44              Strip-District                       0.369996
# 45             Stanton-Heights                       0.366929
# 46                West-oakland                       0.366391
# 47          Point-Breeze North                       0.357950
# 48                 South-Shore                       0.354375
# 49                   Allentown                       0.353925
# 50          Marshall-Shadeland                       0.353353
# 51                      Esplen                       0.348334
# 52                    Sheraden                       0.348089
# 53             Crafton-Heights                       0.344213
# 54                     Elliott                       0.344055
# 55                     Windgap                       0.340615
# 56        Spring-Hill-Cityview                       0.335105
# 57         Upper-Lawrenceville                       0.334694
# 58                   Arlington                       0.334520
# 59               East-Carnegie                       0.332560
# 60                 Perry-North                       0.327275
# 61                 Polish-Hill                       0.320701
# 62         Lower-Lawrenceville                       0.319569
# 63               New-Homestead                       0.316983
# 64                 Perry-North                       0.315350
# 65            Allegheny-Center                       0.313581
# 66                   Troy-Hill                       0.311834
# 67               Spring-Garden                       0.311408
# 68                     Carrick                       0.310517
# 69                   Overbrook                       0.310047
# 70                    Sheraden                       0.308735
# 71               Lincoln-Place                       0.308694
# 72                     Carrick                       0.307687
# 73                        Hays                       0.306539
# 74            Southside-Slopes                       0.303621
# 75                 Summer-Hill                       0.302258
# 76       Central-Lawrenceville                       0.298583
# 77            Brighton-Heights                       0.297589
# 78                     Carrick                       0.296869
# 79                  Greenfield                       0.296250
# 80            Brighton Heights                       0.295853
# 81                   Beechview                       0.295785
# 82                   Overbrook                       0.294503
# 83             Crafton-Heights                       0.293820
# 84            Brighton-Heights                       0.292287
# 85                     Bon-Air                       0.289505
# 86                   Brookline                       0.288113
# 87                    West-End                       0.287904
# 88       Central-Lawrenceville                       0.287296
# 89            Mount-Washington                       0.284662
# 90             Stanton-Heights                       0.283636
# 91            Mount-Washington                       0.283163
# 92                   Beechview                       0.281814
# 93                   Brookline                       0.281736
# 94                  Bloomfield                       0.281425
# 95               South-Oakland                       0.281331
# 96                  Bloomfield                       0.280485
# 97                   Brookline                       0.279140
# 98                   Ridgemont                       0.276786
# 99            Southside-Slopes                       0.276239
# 100                Morningside                       0.275902
# 101                  Brookline                       0.271680
# 102                    Oakwood                       0.268579
# 103                   Westwood                       0.268106
# 104           Mount-Washington                       0.264857
# 105            Southside-Flats                       0.250237
# 106             Swisshelm-Park                       0.249422
# 107           Duquesne-Heights                       0.248010
# 108                      Bluff                       0.246936
# 109            Southside-Flats                       0.244124
# 110              Highland-Park                       0.243037
# 111           Mount-Washington                       0.239972
# 112                 Banksville                       0.239786
# 113                 Bloomfield                       0.233014
# 114                 Greenfield                       0.230732
# 115                 Friendship                       0.220126
# 116              Highland-Park                       0.217420
# 117             Allegheny-West                       0.206399
# 118        Squirrel-Hill South                       0.194095
# 119               Point-Breeze                       0.186204
# 120                 Bloomfield                       0.185610
# 121                 Bloomfield                       0.181224
# 122        Squirrel-Hill South                       0.164996
# 123        Squirrel-Hill North                       0.162826
# 124              Regent-Square                       0.160133
# 125        Squirrel-Hill South                       0.159693
# 126              North-oakland                       0.155867
# 127               Point-Breeze                       0.148784
# 128            Central-Oakland                       0.144556
# 129              North-Oakland                       0.138806
# 130        Squirrel-Hill North                       0.134710
# 131                  Shadyside                       0.134520
# 132                  Shadyside                       0.130383
# 133                  Shadyside                       0.128451
# 134                  Shadyside                       0.126705
# 135                North-Shore                       0.121487
# 136                  Shadyside                       0.118533
# 137            Central-Oakland                       0.112780
# 138        Squirrel-Hill North                       0.080288
# 139              North-Oakland                       0.070353

# %%
new_df_sorted.plot(kind = "bar")
